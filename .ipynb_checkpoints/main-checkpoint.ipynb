# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import cross_val_score

from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Поиск и выбор набора данных для построения моделей машинного обучения. На основе выбранного набора данных студент должен построить модели машинного обучения для решения или задачи классификации, или задачи регрессии.

# %%
origin_data = pd.read_csv('forbes-top-2000-companies/Forbes Top2000 2017.csv')
origin_data.shape
# Out:
# (2000, 10)

# %% [markdown]
# # 2. Проведение разведочного анализа данных. Построение графиков, необходимых для понимания структуры данных. Анализ и заполнение пропусков в данных.

# %%
origin_data.head(10)
# Out:
#    Unnamed: 0   Rank                     Company        Country  Sales  \
# 0         NaN      1                        ICBC          China  151.4
# 1         NaN      2     China Construction Bank          China  134.2
# 2         NaN      3          Berkshire Hathaway  United States  222.9
# 3         NaN      4              JPMorgan Chase  United States  102.5
# 4         NaN      5                 Wells Fargo  United States   97.6
# 5         NaN      6  Agricultural Bank of China          China  115.7
# 6         NaN      7             Bank of America  United States   92.2
# 7         NaN      8               Bank of China          China  113.1
# 8         NaN      9                       Apple  United States  217.5
# 9         NaN     10                Toyota Motor          Japan  249.9
#
#    Profits  Assets  Market Value                  Sector  \
# 0     42.0  3473.2         229.8              Financials
# 1     35.0  3016.6         200.5              Financials
# 2     24.1   620.9         409.9              Financials
# 3     24.2  2513.0         306.6              Financials
# 4     21.9  1943.4         274.4              Financials
# 5     27.8  2816.0         149.2              Financials
# 6     16.6  2196.8         231.9              Financials
# 7     24.9  2611.5         141.3              Financials
# 8     45.2   331.1         752.0  Information Technology
# 9     17.1   412.5         171.9  Consumer Discretionary
#
#                      Industry
# 0                 Major Banks
# 1              Regional Banks
# 2         Investment Services
# 3                 Major Banks
# 4                 Major Banks
# 5              Regional Banks
# 6                 Major Banks
# 7                 Major Banks
# 8           Computer Hardware
# 9  Auto & Truck Manufacturers

# %%
origin_data.dtypes
# Out:
# Unnamed: 0      float64
#  Rank             int64
# Company          object
# Country          object
# Sales           float64
# Profits         float64
# Assets          float64
# Market Value    float64
# Sector           object
# Industry         object
# dtype: object

# %%
origin_data.isnull().sum()
# Out:
# Unnamed: 0      2000
#  Rank              0
# Company            0
# Country            0
# Sales              0
# Profits            0
# Assets             0
# Market Value       0
# Sector           197
# Industry         491
# dtype: int64

# %%
origin_data.drop(["Unnamed: 0", " Rank", "Company"], axis=1, inplace=True)

# %%
origin_data.head(10)
# Out:
#          Country  Sales  Profits  Assets  Market Value  \
# 0          China  151.4     42.0  3473.2         229.8
# 1          China  134.2     35.0  3016.6         200.5
# 2  United States  222.9     24.1   620.9         409.9
# 3  United States  102.5     24.2  2513.0         306.6
# 4  United States   97.6     21.9  1943.4         274.4
# 5          China  115.7     27.8  2816.0         149.2
# 6  United States   92.2     16.6  2196.8         231.9
# 7          China  113.1     24.9  2611.5         141.3
# 8  United States  217.5     45.2   331.1         752.0
# 9          Japan  249.9     17.1   412.5         171.9
#
#                    Sector                    Industry
# 0              Financials                 Major Banks
# 1              Financials              Regional Banks
# 2              Financials         Investment Services
# 3              Financials                 Major Banks
# 4              Financials                 Major Banks
# 5              Financials              Regional Banks
# 6              Financials                 Major Banks
# 7              Financials                 Major Banks
# 8  Information Technology           Computer Hardware
# 9  Consumer Discretionary  Auto & Truck Manufacturers

# %%
origin_data.isnull().sum()
# Out:
# Country           0
# Sales             0
# Profits           0
# Assets            0
# Market Value      0
# Sector          197
# Industry        491
# dtype: int64

# %% [markdown]
# #### Удалим все строчки с пропусками

# %%
# data = origin_data.dropna(axis=0, how='any')
data = origin_data
data['Sector'] = ['Other' if pd.isna(i) else i for i in data['Sector']]
data['Industry'] = ['Other' if pd.isnull(i) else i for i in data['Industry']]
data.is_copy = False

# %% [markdown]
# ### Топ 10 стран по количеству компаний в списке Forbs

# %%
type(data['Country'].value_counts()[:10])
# Out:
# pandas.core.series.Series

# %%
fig, ax = plt.subplots(1,1,figsize=(15,10))
data['Country'].value_counts()[:20].plot(kind='pie', autopct='%.2f', shadow=True);
plt.xlabel("Распределение стран по количеству компаний");

# %% [markdown]
# ### Стандартное распределение доходов компаний

# %%
fig, ax = plt.subplots(figsize=(15,10)) 
sns.distplot(data['Profits'])

# %%
countries = data[['Country', 'Profits']].groupby('Country').sum().sort_values('Profits', ascending=False)[:20]

# %%
countries
# Out:
#                  Profits
# Country
# United States   923.9522
# China           367.7190
# Japan           197.3650
# France           84.3920
# Hong Kong        80.6880
# Germany          66.1590
# United Kingdom   65.7330
# South Korea      65.5960
# Russia           61.1750
# Switzerland      60.2560
# Canada           57.8460
# Australia        48.3260
# Taiwan           40.5220
# India            38.7330
# Ireland          32.3800
# Netherlands      32.0020
# Sweden           31.1830
# Spain            30.4730
# Saudi Arabia     19.0650
# Brazil           17.6080

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))
countries['Profits'].plot(kind='pie', autopct='%.2f', shadow=True);
plt.xlabel("Распределение стран по количеству компаний");

# %%
x = np.arange(20)
plt.bar(x, height= [1,2,3]) 
plt.xticks(x, countries['Country'][:20])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-b995211c8e0f> in <module>
#       1 x = np.arange(3)
#       2 plt.bar(x, height= [1,2,3])
# ----> 3 plt.xticks(x, countries['Country'][:20])
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'

# %% [markdown]
# # 3. Выбор признаков, подходящих для построения моделей. Кодирование категориальных признаков Масштабирование данных. Формирование вспомогательных признаков, улучшающих качество моделей.

# %%
def encode_columns(origin_data):
    data = origin_data
    data.is_copy = False
    encoder = LabelEncoder()
    cols = ["Country", "Sector", "Industry"]

    for col in cols:
        data[col] = encoder.fit_transform(data[col])

    return data

# %%
data = encode_columns(data)

# %% [markdown]
# # 4. Проведение корреляционного анализа данных. Формирование промежуточных выводов о возможности построения моделей машинного обучения. В зависимости от набора данных, порядок выполнения пунктов 2, 3, 4 может быть изменен.

# %%
corr = data.corr(method='pearson')
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_9d039c90_818e_11e9_ae3f_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row0_col1 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row0_col2 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row0_col3 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row0_col4 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row0_col5 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row0_col6 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row1_col0 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row1_col2 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row1_col3 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row1_col4 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row2_col0 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row2_col1 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row2_col3 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row2_col4 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row2_col5 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row2_col6 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row3_col0 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row3_col1 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row3_col2 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row3_col4 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row3_col5 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row3_col6 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row4_col0 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row4_col1 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row4_col2 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row4_col3 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row4_col5 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row4_col6 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row5_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row5_col1 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row5_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row5_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row5_col6 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row6_col0 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row6_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row6_col2 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row6_col3 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row6_col4 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row6_col5 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_9d039c90_818e_11e9_ae3f_acde48001122row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_9d039c90_818e_11e9_ae3f_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country</th>        <th class="col_heading level0 col1" >Sales</th>        <th class="col_heading level0 col2" >Profits</th>        <th class="col_heading level0 col3" >Assets</th>        <th class="col_heading level0 col4" >Market Value</th>        <th class="col_heading level0 col5" >Sector</th>        <th class="col_heading level0 col6" >Industry</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9d039c90_818e_11e9_ae3f_acde48001122level0_row0" class="row_heading level0 row0" >Country</th>
#                         <td id="T_9d039c90_818e_11e9_ae3f_acde48001122row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_9d039c90_818e_11e9_ae3f_acde48001122row0_col1" class="data row0 col1" >0.0232937</td>
#                         <td id="T_9d039c90_818e_11e9_ae3f_acde48001122row0_col2" class="data row0 col2" >0.0313004</td>
#                         <td id="T_9d039c90_818e_11e9_ae3f_acde48001122row0_col3" class="data row0 col3" >-0.0485051</td>
#                         <td id="T_9d039c90_818e_11e9_ae3f_acde48001122row0_col4" class="data row0 col4" >0.11713</td>
#                         <td id="T_9d039c90_818e_11e9_ae3f_acde48001122row0_col5" class="data row0 col5" >-0.064289</td>
#                         <td id="T_9d039c90_818e_11e9_ae3

# %%
# data.drop(['Sector', 'Industry', 'Country'], axis=1, inplace=True)

# %%
data.shape
# Out:
# (2000, 7)

# %%
y = data['Profits']
data_X = data.drop(['Profits'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(data_X, y, random_state = 100, test_size=0.1)

# %% [markdown]
# ### Посмотрим важности признаков с использованием RandomForestRegressor

# %%
def plot_feature_importances():
    rfr_to_plot = RandomForestRegressor(random_state=100)
    rfr_to_plot.fit(X_train, y_train)
    n_features = data.shape[1] - 1
    print(n_features)
    plt.barh(range(n_features), rfr_to_plot.feature_importances_, align='center')
    plt.yticks(np.arange(n_features), [i for i in data.columns if i != 'Profits'])
    plt.xlabel("Важность признаков")
    plt.ylabel("Признаки")
    
plot_feature_importances()
# Out:
# 6

# %% [markdown]
# # 5. Выбор метрик для последующей оценки качества моделей. Необходимо выбрать не менее двух метрик и обосновать выбор.

# %% [markdown]
# Для исследования корректности моделей выберем метрики r2_score, mean_squared_error, mean_absolute_error

# %% [markdown]
# # 6. Выбор наиболее подходящих моделей для решения задачи классификации или регрессии. Необходимо использовать не менее трех моделей, хотя бы одна из которых должна быть ансамблевой.

# %% [markdown]
# Будем исследовать XGBoost, SVR, RandomForestRegressor

# %% [markdown]
# # 7. Формирование обучающей и тестовой выборок на основе исходного набора данных.

# %%
def predict_test(model, X_train, X_test, y_train, y_test):
    pred_train = model.predict(X_train)
    pred_test = model.predict(X_test)

    print('root mean_squared_error train / test: {:0.3f} / {:0.3f}'.format(
        np.sqrt(mean_squared_error(y_train, pred_train)), np.sqrt(mean_squared_error(y_test, pred_test))))
    print('r2_score train / test: {:0.3f} / {:0.3f}'.format(
        r2_score(y_train, pred_train), r2_score(y_test, pred_test)))
    
    
def cvs_test_print(model, X_train, X_test, y_train, y_test, cv=10):
    scores = cross_val_score(model, X_train, y_train, cv=cv)
    print("Значения правильности перекрестной проверки: {}".format(scores))
    print("Среднее: {}.\nМаксимальное: {}.\nМинимальное: {}".format(np.mean(scores), np.max(scores), np.min(scores)))
    

def compare_predictions(model, test_data, y_test):
    fig, ax = plt.subplots(figsize=(15,10)) 
    plt.plot(np.linspace(0, len(y_test), len(test_data)), model.predict(test_data))
    plt.plot(np.linspace(0, len(y_test), len(y_test)), y_test)

# %%
scaler = MinMaxScaler().fit(X_train)
X_train_scaled, X_test_scaled = scaler.transform(X_train), scaler.transform(X_test)

# %% [markdown]
# # 8. Построение базового решения (baseline) для выбранных моделей без подбора гиперпараметров. Производится обучение моделей на основе обучающей выборки и оценка качества моделей на основе тестовой выборки.

# %% [markdown]
# #### XGBRegressor

# %%
xgb = XGBRegressor(objective='reg:linear')
cvs_test_print(xgb, X_train_scaled, X_test_scaled, y_train, y_test)

xgb.fit(X_train_scaled, y_train)
predict_test(xgb, X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# [00:21:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Значения правильности перекрестной проверки: [0.12832129 0.64620349 0.02117703 0.69392116 0.43500426 0.32409968
#  0.76928089 0.81226802 0.57296362 0.64586453]
# Среднее: 0.5049103960182665.
# Максимальное: 0.8122680163607557.
# Минимальное: 0.021177030914538264
# [00:21:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# root mean_squared_error train / test: 1.076 / 1.695
# r2_score train / test: 0.868 / 0.527

# %% [markdown]
# #### SVR

# %%
svr = SVR().fit(X_train_scaled, y_train)
cvs_test_print(svr, X_train_scaled, X_test_scaled, y_train, y_test)
predict_test(svr, X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# Значения правильности перекрестной проверки: [0.40635753 0.33678538 0.26978726 0.46943239 0.32993553 0.23841765
#  0.37125101 0.32014133 0.30767466 0.35199405]
# Среднее: 0.34017767863356574.
# Максимальное: 0.4694323907342888.
# Минимальное: 0.23841764518380437
# root mean_squared_error train / test: 2.333 / 1.862
# r2_score train / test: 0.381 / 0.430

# %% [markdown]
# #### RFR

# %%
rfr = RandomForestRegressor().fit(X_train_scaled, y_train)
cvs_test_print(rfr, X_train_scaled, X_test_scaled, y_train, y_test)
predict_test(rfr, X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# Значения правильности перекрестной проверки: [0.13156046 0.66607328 0.15961847 0.68782341 0.47349691 0.20272385
#  0.68453232 0.83512955 0.47861754 0.68876102]
# Среднее: 0.5008336803203646.
# Максимальное: 0.8351295467062702.
# Минимальное: 0.13156045530316673
# root mean_squared_error train / test: 0.711 / 1.550
# r2_score train / test: 0.943 / 0.605

# %% [markdown]
# # 9. Подбор гиперпараметров для выбранных моделей.
# # 10. Повторение пункта 8 для найденных оптимальных значений гиперпараметров. Сравнение качества полученных моделей с качеством baseline-моделей.

# %% [markdown]
# #### XGBRegressor

# %%
xgb_grid_params = {
    'n_estimators': [10, 20, 50, 100, 200, 300, 500, 600, 700]
}

xgb_grid = GridSearchCV(XGBRegressor(), xgb_grid_params, cv = 10)
xgb_grid.fit(X_train, y_train)
# Out:
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:21:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:22:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=1, verbosity=1),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'n_estimators': [10, 20, 50, 100, 200, 300, 500, 600, 700]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
print("Лучший результат модели XGBoost с использованием GridSearchCV:",
      xgb_grid.best_score_)
print("Наилучшие значения параметров: {}".format(xgb_grid.best_params_))
# Out:
# Лучший результат модели XGBoost с использованием GridSearchCV: 0.5195560618389029
# Наилучшие значения параметров: {'n_estimators': 500}

# %% [markdown]
# #### RFR

# %%
rfr_grid_params = {
    'max_depth': [5, 10, 20, 40, 60, 90],
}

rfr_grid = GridSearchCV(RandomForestRegressor(), rfr_grid_params, cv=10)
rfr_grid.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'max_depth': [5, 10, 20, 40, 60, 90]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
print("Лучший результат модели RandomForestRegressor с использованием GridSearchCV:",
      rfr_grid.best_score_)
print("Наилучшие значения параметров: {}".format(rfr_grid.best_params_))
predict_test(rfr_grid, X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# Лучший результат модели RandomForestRegressor с использованием GridSearchCV: 0.5012337093075161
# Наилучшие значения параметров: {'max_depth': 20}
# root mean_squared_error train / test: 0.756 / 1.420
# r2_score train / test: 0.935 / 0.668

# %% [markdown]
# #### SVR

# %%
svr_grid_params = {'C': np.array([0.1, 1, 10, 100, 1000]), 'gamma': np.array([0.001, 0.01, 0.1, 1, 10])}
svr_grid = GridSearchCV(SVR(), svr_grid_params, cv=5)
svr_grid.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'C': array([1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03]), 'gamma': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
print("Наил знач правильности перекр проверки: {:.2f}".format(svr_grid.best_score_))
print("Наил знач правильности на тесте: {:.2f}".format(svr_grid.score(X_test_scaled, y_test)))
print("Наил параметры: ", svr_grid.best_params_)
# Out:
# Наил знач правильности перекр проверки: 0.58
# Наил знач правильности на тесте: 0.76
# Наил параметры:  {'C': 1000.0, 'gamma': 0.01}

# %% [markdown]
# # 11. Формирование выводов о качестве построенных моделей на основе выбранных метрик.

# %% [markdown]
# ### Из вышеприведенных исследований можно сделать вывод, что лучшей среди всех используемых моделей оказалась SVR.
#
# Наилучшее значечние правильности cros_val_score: 0.62
# Наилучшее значение правильности на тесте: 0.76
# Наилучгие параметры:  {'C': 1000.0, 'gamma': 1.0}

# %%
compare_predictions(svr_grid, X_test_scaled, y_test)

# %%
predict_test(svr_grid, X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# root mean_squared_error train / test: 1.725 / 1.220
# r2_score train / test: 0.661 / 0.755

# %% [markdown]
# ### Видно, средняя квадратическая ошибка чуть больше 1 миллиарда долларов
