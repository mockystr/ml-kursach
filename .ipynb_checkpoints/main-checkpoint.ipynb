# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error, mean_absolute_error
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import cross_val_score

from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
origin_data = pd.read_csv('forbes-top-2000-companies/Forbes Top2000 2017.csv')
origin_data.shape
# Out:
# (2000, 10)

# %% [markdown]
# # Исследование датасета

# %%
origin_data.head(10)
# Out:
#    Unnamed: 0   Rank                     Company        Country  Sales  \
# 0         NaN      1                        ICBC          China  151.4
# 1         NaN      2     China Construction Bank          China  134.2
# 2         NaN      3          Berkshire Hathaway  United States  222.9
# 3         NaN      4              JPMorgan Chase  United States  102.5
# 4         NaN      5                 Wells Fargo  United States   97.6
# 5         NaN      6  Agricultural Bank of China          China  115.7
# 6         NaN      7             Bank of America  United States   92.2
# 7         NaN      8               Bank of China          China  113.1
# 8         NaN      9                       Apple  United States  217.5
# 9         NaN     10                Toyota Motor          Japan  249.9
#
#    Profits  Assets  Market Value                  Sector  \
# 0     42.0  3473.2         229.8              Financials
# 1     35.0  3016.6         200.5              Financials
# 2     24.1   620.9         409.9              Financials
# 3     24.2  2513.0         306.6              Financials
# 4     21.9  1943.4         274.4              Financials
# 5     27.8  2816.0         149.2              Financials
# 6     16.6  2196.8         231.9              Financials
# 7     24.9  2611.5         141.3              Financials
# 8     45.2   331.1         752.0  Information Technology
# 9     17.1   412.5         171.9  Consumer Discretionary
#
#                      Industry
# 0                 Major Banks
# 1              Regional Banks
# 2         Investment Services
# 3                 Major Banks
# 4                 Major Banks
# 5              Regional Banks
# 6                 Major Banks
# 7                 Major Banks
# 8           Computer Hardware
# 9  Auto & Truck Manufacturers

# %%
origin_data.dtypes
# Out:
# Unnamed: 0      float64
#  Rank             int64
# Company          object
# Country          object
# Sales           float64
# Profits         float64
# Assets          float64
# Market Value    float64
# Sector           object
# Industry         object
# dtype: object

# %%
origin_data.isnull().sum()
# Out:
# Unnamed: 0      2000
#  Rank              0
# Company            0
# Country            0
# Sales              0
# Profits            0
# Assets             0
# Market Value       0
# Sector           197
# Industry         491
# dtype: int64

# %%
origin_data.drop(["Unnamed: 0", " Rank", "Company"], axis=1, inplace=True)

# %%
origin_data.head(10)
# Out:
#          Country  Sales  Profits  Assets  Market Value  \
# 0          China  151.4     42.0  3473.2         229.8
# 1          China  134.2     35.0  3016.6         200.5
# 2  United States  222.9     24.1   620.9         409.9
# 3  United States  102.5     24.2  2513.0         306.6
# 4  United States   97.6     21.9  1943.4         274.4
# 5          China  115.7     27.8  2816.0         149.2
# 6  United States   92.2     16.6  2196.8         231.9
# 7          China  113.1     24.9  2611.5         141.3
# 8  United States  217.5     45.2   331.1         752.0
# 9          Japan  249.9     17.1   412.5         171.9
#
#                    Sector                    Industry
# 0              Financials                 Major Banks
# 1              Financials              Regional Banks
# 2              Financials         Investment Services
# 3              Financials                 Major Banks
# 4              Financials                 Major Banks
# 5              Financials              Regional Banks
# 6              Financials                 Major Banks
# 7              Financials                 Major Banks
# 8  Information Technology           Computer Hardware
# 9  Consumer Discretionary  Auto & Truck Manufacturers

# %%
origin_data.isnull().sum()
# Out:
# Country           0
# Sales             0
# Profits           0
# Assets            0
# Market Value      0
# Sector          197
# Industry        491
# dtype: int64

# %%
data = origin_data.dropna(axis=0, how='any')
data.is_copy = False

# %%
data['Country'].value_counts()[:10]
# Out:
# United States     410
# Japan             192
# China             110
# United Kingdom     72
# France             51
# India              49
# South Korea        47
# Canada             44
# Taiwan             41
# Germany            40
# Name: Country, dtype: int64

# %%
fig, ax = plt.subplots(1,1,figsize=(15,10))
data['Country'].value_counts()[:20].plot(kind='pie', autopct='%.2f', shadow=True);
plt.xlabel("Распределение топ 20 компаний по странам");

# %%
fig, ax = plt.subplots(figsize=(15,10)) 
sns.distplot(data['Profits'])

# %%
def encode_columns(origin_data):
    data = origin_data
    data.is_copy = False
    encoder = LabelEncoder()
    cols = ["Country", "Sector", "Industry"]

    for col in cols:
        data[col] = encoder.fit_transform(data[col])

    return data

# %%
data = encode_columns(data)

# %%
y = data['Profits']
data_X = data.drop(['Profits'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(data_X, y, random_state = 100, test_size=0.1)

# %%
def plot_feature_importances():
    rfr_to_plot = RandomForestRegressor(random_state=100)
    rfr_to_plot.fit(X_train, y_train)
    n_features = data.shape[1] - 1
    plt.barh(range(n_features), rfr_to_plot.feature_importances_, align='center')
    plt.yticks(np.arange(n_features), [i for i in data.columns if i != 'Profits'])
    plt.xlabel("Важность признаков")
    plt.ylabel("Признаки")
    
plot_feature_importances()

# %% [markdown]
# # Создание моделей

# %% [markdown]
# Будем исследовать XGBoost, SVR, RandomForestRegressor

# %%
def predict_test(model, X_train, X_test, y_train, y_test):
    pred_train = model.predict(X_train)
    pred_test = model.predict(X_test)

    print('root mean_squared_error train / test: {:0.3f} / {:0.3f}'.format(
        np.sqrt(mean_squared_error(y_train, pred_train)), np.sqrt(mean_squared_error(y_test, pred_test))))
    print('r2_score train / test: {:0.3f} / {:0.3f}'.format(
        r2_score(y_train, pred_train), r2_score(y_test, pred_test)))
    
    
def cvs_test_print(model, X_train, X_test, y_train, y_test, cv=10):
    scores = cross_val_score(model, X_train, y_train, cv=cv)
    print("Значения правильности перекрестной проверки: {}".format(scores))
    print("Среднее: {}.\nМаксимальное: {}.\nМинимальное: {}".format(np.mean(scores), np.max(scores), np.min(scores)))
    

def compare_predictions(model, test_data, y_test):
    plt.plot(y_test, model.predict(test_data))
    
    for i in zip(y_test, model.predict(test_data)):
        print(i)
        
    print(model.predict(test_data))

# %%
scaler = MinMaxScaler().fit(X_train)
X_train_scaled, X_test_scaled = scaler.transform(X_train), scaler.transform(X_test)

# %% [markdown]
# #### XGBRegressor

# %%
xgb = XGBRegressor(objective='reg:linear')
cvs_test_print(xgb, X_train, X_test, y_train, y_test)

xgb.fit(X_train, y_train)
predict_test(xgb, X_train, X_test, y_train, y_test)
compare_predictions(xgb, X_test, y_test)
# Out:
# [18:24:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Значения правильности перекрестной проверки: [0.62340742 0.62003689 0.65649444 0.31749559 0.53188976 0.46311515
#  0.80875176 0.77497396 0.14110075 0.76801187]
# Среднее: 0.570527759648789.
# Максимальное: 0.8087517646624529.
# Минимальное: 0.14110074934524952
# [18:24:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# root mean_squared_error train / test: 1.130 / 1.526
# r2_score train / test: 0.886 / 0.490
# (0.43700000000000006, 0.4506)
# (0.6579999999999999, 0.31151015)
# (-0.44, 0.36069667)
# (0.17600000000000002, 1.1576935)
# (2.3, 1.5275508)
# (0.797, 0.8285735)
# (0.696, 0.08881137)
# (0.457, 0.6879021)
# (0.512, 0.29304153)
# (0.49200000000000005, 0.3604735)
# (-0.444, 0.41785023)
# (2.2, 1.7143645)
# (2.9, 1.5323918)
# (1.2, 0.44293237)
# (1.6, 1.0723708)
# (-0.036000000000000004, 0.88615495)
# (0.345, 0.12867779)
# (0.649, 0.49511027)
# (0.7340000000000001, 0.24959433)
# (0.821, 0.91768575)
# (0.513, 0.69490904)
# (3.8, 1.9077512)
# (0.075, -1.565716)
# (1.6, 1.3255775)
# (0.457, 0.4584113)
# (0.146, 0.23005265)
# (0.424, 0.48255807)
# (0.083, 0.22299004)
# (0.9490000000000001, 1.4897661)
# (0.478, 0.4492632)
# (0.249, 0.10283491)
# (1.1, 1.209385)
# (1.2, 1.1988039)
# (0.418, 0.29304153)
# (0.425, 0.46188825)
# (1.0, 0.9046495)
# (2.0, 0.77206266)
# (-0.11, 0.031879634)
# (3.6, 1.7023449)
# (3.0, 1.9865485)
# (-2.0, 0.6057556)
# (1.2, 1.0936964)
# (1.7, 1.1408119)
# (2.4, 1.0189481)
# (0.836, 0.6386612)
# (1.5, 0.9709664)
# (0.19399999999999998, 0.28652665)
# (4.7, 3.879541)
# (0.41700000000000004, 0.39662585)
# (4.6, 6.080952)
# (-6.2, 0.6593056)
# (0.47700000000000004, 1.1334757)
# (0.431, 0.15660453)
# (1.2, 1.570344)
# (0.46799999999999997, 0.63761735)
# (0.031, 0.52573085)
# (1.1, 0.6772636)
# (1.2, 4.636082)
# (1.8, 0.9557109)
# (10.0, 19.369932)
# (0.489, 0.63834476)
# (1.7, 0.8285735)
# (0.42700000000000005, 0.4506)
# (3.8, 4.5781827)
# (1.2, 1.7981609)
# (0.902, 0.7329773)
# (0.431, 0.39609182)
# (1.8, 1.7074697)
# (4.3, 3.7089956)
# (0.539, 0.5555652)
# (10.1, 3.1002028)
# (1.1, 1.1071463)
# (4.5, 4.096677)
# (0.314, 0.47103637)
# (1.4, 1.135526)
# (1.6, 0.6411909)
# (0.469, 0.46470186)
# (0.105, 0.2070286)
# (1.1, 0.6471536)
# (0.281, 0.4273721)
# (2.7, 1.7519454)
# (0.256, 0.16845703)
# (1.3, 0.9265553)
# (0.252, 0.5584713)
# (0.449, 0.20295641)
# (1.4, 1.0756704)
# (0.6679999999999999, 0.5215606)
# (2.0, 4.4630833)
# (2.2, 1.6037577)
# (0.45799999999999996, 0.40806034)
# (0.758, 0.6432905)
# (1.1, 1.3996586)
# (0.473, 0.5795708)
# (0.41600000000000004, 0.6197859)
# (0.495, 0.41461563)
# (1.3, 1.0534996)
# (0.125, 0.06881192)
# (0.659, 0.6432905)
# (16.4, 9.339617)
# (1.5, 1.5269036)
# (2.0, 1.1867332)
# (2.1, 1.9697804)
# (0.106, 0.7089141)
# (0.613, 0.50394267)
# (0.664, 0.6173936)
# (0.6679999999999999, 0.6592818)
# (0.485, 0.5146407)
# (0.203, 0.23365691)
# (0.935, 0.6760003)
# (1.0, 1.2866731)
# (1.5, 1.8976276)
# (1.7, 1.7597625)
# (0.27, 0.27478153)
# (1.7, 1.6119974)
# (-2.1, 0.11203781)
# (-3.6, 1.1262401)
# (0.821, 0.8625719)
# (0.846, 0.35268486)
# (0.5720000000000001, 0.13774374)
# (0.568, 1.1294873)
# (1.4, 1.2733145)
# (0.655, 0.50805116)
# (1.7, 0.85460186)
# (0.483, 2.5351844)
# (2.5, 2.189022)
# (0.965, 0.9255859)
# (6.9, 5.644042)
# (2.3, 1.6039495)
# (1.4, 0.74855787)
# (-0.136, 0.54420555)
# (0.735, 0.7347959)
# (0.653, 0.63761735)
# (1.0, 0.88186)
# (0.568, 0.6060239)
# (0.6990000000000001, 1.5201758)
# (0.614, 0.44824988)
# (0.16699999999999998, 0.55680114)
# (4.6, 2.150127)
# (1.6, 1.5116955)
# (0.866, 0.3376536)
# (0.327, 0.3582068)
# (0.825, 1.5066252)
# (0.977, 0.2674923)
# (0.439, 0.4458492)
# (1.2, -0.1738776)
# (1.9, 1.2888463)
# (0.34700000000000003, 0.8969984)
# (0.627, 0.44824988)
# (0.474, 0.39658284)
# (-3.2, 0.27025896)
# (0.249, 0.27025896)
# [ 0.4506      0.31151015  0.36069667  1.1576935   1.5275508   0.8285735
#   0.08881137  0.6879021   0.29304153  0.3604735   0.41785023  1.7143645
#   1.5323918   0.44293237  1.0723708   0.88615495  0.12867779  0.49511027
#   0.24959433  0.91768575  0.69490904  1.9077512  -1.565716    1.3255775
#   0.4584113   0.23005265  0.48255807  0.22299004  1.4897661   0.4492632
#   0.10283491  1.209385    1.1988039   0.29304153  0.46188825  0.9046495
#   0.77206266  0.03187963  1.7023449   1.9865485   0.6057556   1.0936964
#   1.1408119   1.0189481   0.6386612   0.9709664   0.28652665  3.879541
#   0.39662585  6.080952    0.6593056   1.1334757   0.15660453  1.570344
#   0.63761735  0.52573085  0.6772636   4.636082    0.9557109  19.369932
#   0.63834476  0.8285735   0.4506      4.5781827   1.7981609   0.7329773
#   0.39609182  1.7074697   3.7089956   0.5555652   3.1002028   1.1071463
#   4.096677    0.47103637  1.135526    0.6411909   0.46470186  0.2070286
#   0.6471536   0.4273721   1.7519454   0.16845703  0.9265553   0.5584713
#   0.20295641  1.0756704   0.5215606   4.4630833   1.6037577   0.40806034
#   0.6432905   1.3996586   0.5795708   0.6197859   0.41461563  1.0534996
#   0.06881192  0.6432905   9.339617    1.5269036   1.1867332   1.9697804
#   0.7089141   0.50394267  0.6173936   0.6592818   0.5146407   0.23365691
#   0.6760003   1.2866731   1.8976276   1.7597625   0.27478153  1.6119974
#   0.11203781  1.1262401   0.8625719   0.35268486  0.13774374  1.1294873
#   1.2733145   0.50805116  0.85460186  2.5351844   2.189022    0.9255859
#   5.644042    1.6039495   0.74855787  0.54420555  0.7347959   0.63761735
#   0.88186     0.6060239   1.5201758   0.44824988  0.55680114  2.150127
#   1.5116955   0.3376536   0.3582068   1.5066252   0.2674923   0.4458492
#  -0.1738776   1.2888463   0.8969984   0.44824988  0.39658284  0.27025896
#   0.27025896]

# %% [markdown]
# #### SVR

# %%
svr = SVR().fit(X_train_scaled, y_train)
cvs_test_print(svr, X_train_scaled, X_test_scaled, y_train, y_test)
predict_test(svr, X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# Значения правильности перекрестной проверки: [0.31133742 0.314867   0.37358075 0.25784723 0.29663169 0.289661
#  0.36364787 0.2725632  0.28837085 0.32027269]
# Среднее: 0.30887797067013284.
# Максимальное: 0.37358074836335564.
# Минимальное: 0.2578472312213296
# root mean_squared_error train / test: 2.704 / 1.666
# r2_score train / test: 0.346 / 0.392

# %%
compare_predictions(svr, X_test_scaled, y_test)
# Out:
# (0.43700000000000006, 0.6162592466539705)
# (0.6579999999999999, 0.6476391902322267)
# (-0.44, 0.6425263704066349)
# (0.17600000000000002, 0.9595064489100897)
# (2.3, 1.5385853691406581)
# (0.797, 0.5631212250772251)
# (0.696, 0.6292459477014907)
# (0.457, 0.5443932546375203)
# (0.512, 0.5472961358001966)
# (0.49200000000000005, 0.6349150777062711)
# (-0.444, 0.6113741041959591)
# (2.2, 1.219845816332584)
# (2.9, 1.462413972450709)
# (1.2, 0.6311350052422666)
# (1.6, 0.8475253784334074)
# (-0.036000000000000004, 0.6600212756446773)
# (0.345, 0.47415629136541027)
# (0.649, 0.6577315077221488)
# (0.7340000000000001, 0.5851597513921503)
# (0.821, 0.7502901243890934)
# (0.513, 0.7215376002185665)
# (3.8, 1.1887537907508063)
# (0.075, 0.4627633669683373)
# (1.6, 0.9523277573156661)
# (0.457, 0.619010719201925)
# (0.146, 0.4595839163140507)
# (0.424, 0.7828043777535303)
# (0.083, 0.5448983695535015)
# (0.9490000000000001, 2.10458979697467)
# (0.478, 0.6014475505622627)
# (0.249, 0.4888762654651706)
# (1.1, 1.025844603564452)
# (1.2, 0.9159003777896377)
# (0.418, 0.5510376391308309)
# (0.425, 0.7087582266197885)
# (1.0, 0.6407710039668566)
# (2.0, 0.7738968192703564)
# (-0.11, 0.4575985064589698)
# (3.6, 1.4267070949745406)
# (3.0, 1.4001026629849285)
# (-2.0, 0.8038276196620344)
# (1.2, 0.8816535544004478)
# (1.7, 0.9724064178887426)
# (2.4, 0.9203721810014125)
# (0.836, 0.6848501386567349)
# (1.5, 0.9901760984790433)
# (0.19399999999999998, 0.47974878047577274)
# (4.7, 1.6766646017479365)
# (0.41700000000000004, 0.753605578984647)
# (4.6, 2.643763771343507)
# (-6.2, 0.8238345481884646)
# (0.47700000000000004, 1.0026211416986421)
# (0.431, 0.6803609867943949)
# (1.2, 0.9788712247290001)
# (0.46799999999999997, 0.6951190902702455)
# (0.031, 0.6581948518110439)
# (1.1, 0.567002510740886)
# (1.2, 1.8522111024426078)
# (1.8, 0.7873867776451033)
# (10.0, 4.5615327708808655)
# (0.489, 0.735103602517259)
# (1.7, 0.6854905690471349)
# (0.42700000000000005, 0.6555330286102987)
# (3.8, 1.4635653140804836)
# (1.2, 0.7954583711885959)
# (0.902, 0.683957254227618)
# (0.431, 0.6979281009157103)
# (1.8, 0.9295843956515806)
# (4.3, 1.742341131180678)
# (0.539, 0.7269193589034817)
# (10.1, 3.3100245985585692)
# (1.1, 0.6911058474611043)
# (4.5, 1.521260455810535)
# (0.314, 0.5483259970332957)
# (1.4, 0.9543523492031663)
# (1.6, 0.5867693032356205)
# (0.469, 0.7995783891676997)
# (0.105, 0.45139292603852565)
# (1.1, 0.7389959244366227)
# (0.281, 0.7151924495312638)
# (2.7, 1.1997089547496376)
# (0.256, 0.5659496143049974)
# (1.3, 0.8596182505712793)
# (0.252, 0.553908227048657)
# (0.449, 0.5362738890464427)
# (1.4, 0.9725710896530908)
# (0.6679999999999999, 0.6823067873606217)
# (2.0, 1.5719733841600927)
# (2.2, 1.1906716769740668)
# (0.45799999999999996, 0.6352110699666409)
# (0.758, 0.7128221327635134)
# (1.1, 0.9773089412955698)
# (0.473, 0.6988890946810371)
# (0.41600000000000004, 0.699001234376931)
# (0.495, 0.5947327015788284)
# (1.3, 0.6954049073646056)
# (0.125, 0.43695953740533167)
# (0.659, 0.7165959574817053)
# (16.4, 4.559539690397727)
# (1.5, 1.5341690723271835)
# (2.0, 0.8955785907582516)
# (2.1, 1.1601740154263969)
# (0.106, 0.7867591121055479)
# (0.613, 0.8246745208310269)
# (0.664, 0.7466599625785864)
# (0.6679999999999999, 0.6999414632047043)
# (0.485, 0.5264337084596127)
# (0.203, 0.5899067035923773)
# (0.935, 0.7102942309326998)
# (1.0, 1.192925376192138)
# (1.5, 0.9363257795253306)
# (1.7, 0.8083301677312367)
# (0.27, 0.5455058324958895)
# (1.7, 1.7192347811929478)
# (-2.1, 0.5700114512603864)
# (-3.6, 0.7832464064019709)
# (0.821, 0.8292546230684672)
# (0.846, 0.5210571592377855)
# (0.5720000000000001, 0.5126064184927754)
# (0.568, 0.9063642313303073)
# (1.4, 0.8537446002443088)
# (0.655, 0.5859153103532795)
# (1.7, 1.1772491542071708)
# (0.483, 2.149406640275124)
# (2.5, 1.2722620746798783)
# (0.965, 0.7322263566055964)
# (6.9, 3.8655773617100664)
# (2.3, 1.8263678331819007)
# (1.4, 0.8700531840816983)
# (-0.136, 0.6836905855047704)
# (0.735, 0.6942935416569687)
# (0.653, 0.7223634622065471)
# (1.0, 0.7421091747601749)
# (0.568, 0.6134193087838185)
# (0.6990000000000001, 1.0164937103470362)
# (0.614, 0.6920496006607424)
# (0.16699999999999998, 0.5637213759951782)
# (4.6, 1.7644505399292858)
# (1.6, 1.165962026738787)
# (0.866, 0.699688290984469)
# (0.327, 0.6140877025728448)
# (0.825, 1.4102397987163457)
# (0.977, 0.624558819881889)
# (0.439, 0.4644679519962964)
# (1.2, 0.38411039313432127)
# (1.9, 1.0921662924397284)
# (0.34700000000000003, 0.8613077008247565)
# (0.627, 0.6330576632602511)
# (0.474, 0.5515668317106477)
# (-3.2, 0.5469319438979778)
# (0.249, 0.5782132990992039)
# [0.61625925 0.64763919 0.64252637 0.95950645 1.53858537 0.56312123
#  0.62924595 0.54439325 0.54729614 0.63491508 0.6113741  1.21984582
#  1.46241397 0.63113501 0.84752538 0.66002128 0.47415629 0.65773151
#  0.58515975 0.75029012 0.7215376  1.18875379 0.46276337 0.95232776
#  0.61901072 0.45958392 0.78280438 0.54489837 2.1045898  0.60144755
#  0.48887627 1.0258446  0.91590038 0.55103764 0.70875823 0.640771
#  0.77389682 0.45759851 1.42670709 1.40010266 0.80382762 0.88165355
#  0.97240642 0.92037218 0.68485014 0.9901761  0.47974878 1.6766646
#  0.75360558 2.64376377 0.82383455 1.00262114 0.68036099 0.97887122
#  0.69511909 0.65819485 0.56700251 1.8522111  0.78738678 4.56153277
#  0.7351036  0.68549057 0.65553303 1.46356531 0.79545837 0.68395725
#  0.6979281  0.9295844  1.74234113 0.72691936 3.3100246  0.69110585
#  1.52126046 0.548326   0.95435235 0.5867693  0.79957839 0.45139293
#  0.73899592 0.71519245 1.19970895 0.56594961 0.85961825 0.55390823
#  0.53627389 0.97257109 0.68230679 1.57197338 1.19067168 0.63521107
#  0.71282213 0.97730894 0.69888909 0.69900123 0.5947327  0.69540491
#  0.43695954 0.71659596 4.55953969 1.53416907 0.89557859 1.16017402
#  0.78675911 0.82467452 0.74665996 0.69994146 0.52643371 0.5899067
#  0.71029423 1.19292538 0.93632578 0.80833017 0.54550583 1.71923478
#  0.57001145 0.78324641 0.82925462 0.52105716 0.51260642 0.90636423
#  0.8537446  0.58591531 1.17724915 2.14940664 1.27226207 0.73222636
#  3.86557736 1.82636783 0.87005318 0.68369059 0.69429354 0.72236346
#  0.74210917 0.61341931 1.01649371 0.6920496  0.56372138 1.76445054
#  1.16596203 0.69968829 0.6140877  1.4102398  0.62455882 0.46446795
#  0.38411039 1.09216629 0.8613077  0.63305766 0.55156683 0.54693194
#  0.5782133 ]

# %% [markdown]
# #### RFR

# %%
rfr = RandomForestRegressor(max_depth=2).fit(X_train_scaled, y_train)
cvs_test_print(rfr, X_train_scaled, X_test_scaled, y_train, y_test)
predict_test(rfr, X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# Значения правильности перекрестной проверки: [0.40786769 0.47544911 0.68695447 0.30469668 0.35442367 0.36193596
#  0.76603125 0.59621319 0.31767058 0.59988163]
# Среднее: 0.4871124231774083.
# Максимальное: 0.7660312501074178.
# Минимальное: 0.30469668189172827
# root mean_squared_error train / test: 1.957 / 1.477
# r2_score train / test: 0.657 / 0.522

# %%
compare_predictions(svr, X_test_scaled, y_test)
# Out:
# (0.43700000000000006, 0.6162592466539705)
# (0.6579999999999999, 0.6476391902322267)
# (-0.44, 0.6425263704066349)
# (0.17600000000000002, 0.9595064489100897)
# (2.3, 1.5385853691406581)
# (0.797, 0.5631212250772251)
# (0.696, 0.6292459477014907)
# (0.457, 0.5443932546375203)
# (0.512, 0.5472961358001966)
# (0.49200000000000005, 0.6349150777062711)
# (-0.444, 0.6113741041959591)
# (2.2, 1.219845816332584)
# (2.9, 1.462413972450709)
# (1.2, 0.6311350052422666)
# (1.6, 0.8475253784334074)
# (-0.036000000000000004, 0.6600212756446773)
# (0.345, 0.47415629136541027)
# (0.649, 0.6577315077221488)
# (0.7340000000000001, 0.5851597513921503)
# (0.821, 0.7502901243890934)
# (0.513, 0.7215376002185665)
# (3.8, 1.1887537907508063)
# (0.075, 0.4627633669683373)
# (1.6, 0.9523277573156661)
# (0.457, 0.619010719201925)
# (0.146, 0.4595839163140507)
# (0.424, 0.7828043777535303)
# (0.083, 0.5448983695535015)
# (0.9490000000000001, 2.10458979697467)
# (0.478, 0.6014475505622627)
# (0.249, 0.4888762654651706)
# (1.1, 1.025844603564452)
# (1.2, 0.9159003777896377)
# (0.418, 0.5510376391308309)
# (0.425, 0.7087582266197885)
# (1.0, 0.6407710039668566)
# (2.0, 0.7738968192703564)
# (-0.11, 0.4575985064589698)
# (3.6, 1.4267070949745406)
# (3.0, 1.4001026629849285)
# (-2.0, 0.8038276196620344)
# (1.2, 0.8816535544004478)
# (1.7, 0.9724064178887426)
# (2.4, 0.9203721810014125)
# (0.836, 0.6848501386567349)
# (1.5, 0.9901760984790433)
# (0.19399999999999998, 0.47974878047577274)
# (4.7, 1.6766646017479365)
# (0.41700000000000004, 0.753605578984647)
# (4.6, 2.643763771343507)
# (-6.2, 0.8238345481884646)
# (0.47700000000000004, 1.0026211416986421)
# (0.431, 0.6803609867943949)
# (1.2, 0.9788712247290001)
# (0.46799999999999997, 0.6951190902702455)
# (0.031, 0.6581948518110439)
# (1.1, 0.567002510740886)
# (1.2, 1.8522111024426078)
# (1.8, 0.7873867776451033)
# (10.0, 4.5615327708808655)
# (0.489, 0.735103602517259)
# (1.7, 0.6854905690471349)
# (0.42700000000000005, 0.6555330286102987)
# (3.8, 1.4635653140804836)
# (1.2, 0.7954583711885959)
# (0.902, 0.683957254227618)
# (0.431, 0.6979281009157103)
# (1.8, 0.9295843956515806)
# (4.3, 1.742341131180678)
# (0.539, 0.7269193589034817)
# (10.1, 3.3100245985585692)
# (1.1, 0.6911058474611043)
# (4.5, 1.521260455810535)
# (0.314, 0.5483259970332957)
# (1.4, 0.9543523492031663)
# (1.6, 0.5867693032356205)
# (0.469, 0.7995783891676997)
# (0.105, 0.45139292603852565)
# (1.1, 0.7389959244366227)
# (0.281, 0.7151924495312638)
# (2.7, 1.1997089547496376)
# (0.256, 0.5659496143049974)
# (1.3, 0.8596182505712793)
# (0.252, 0.553908227048657)
# (0.449, 0.5362738890464427)
# (1.4, 0.9725710896530908)
# (0.6679999999999999, 0.6823067873606217)
# (2.0, 1.5719733841600927)
# (2.2, 1.1906716769740668)
# (0.45799999999999996, 0.6352110699666409)
# (0.758, 0.7128221327635134)
# (1.1, 0.9773089412955698)
# (0.473, 0.6988890946810371)
# (0.41600000000000004, 0.699001234376931)
# (0.495, 0.5947327015788284)
# (1.3, 0.6954049073646056)
# (0.125, 0.43695953740533167)
# (0.659, 0.7165959574817053)
# (16.4, 4.559539690397727)
# (1.5, 1.5341690723271835)
# (2.0, 0.8955785907582516)
# (2.1, 1.1601740154263969)
# (0.106, 0.7867591121055479)
# (0.613, 0.8246745208310269)
# (0.664, 0.7466599625785864)
# (0.6679999999999999, 0.6999414632047043)
# (0.485, 0.5264337084596127)
# (0.203, 0.5899067035923773)
# (0.935, 0.7102942309326998)
# (1.0, 1.192925376192138)
# (1.5, 0.9363257795253306)
# (1.7, 0.8083301677312367)
# (0.27, 0.5455058324958895)
# (1.7, 1.7192347811929478)
# (-2.1, 0.5700114512603864)
# (-3.6, 0.7832464064019709)
# (0.821, 0.8292546230684672)
# (0.846, 0.5210571592377855)
# (0.5720000000000001, 0.5126064184927754)
# (0.568, 0.9063642313303073)
# (1.4, 0.8537446002443088)
# (0.655, 0.5859153103532795)
# (1.7, 1.1772491542071708)
# (0.483, 2.149406640275124)
# (2.5, 1.2722620746798783)
# (0.965, 0.7322263566055964)
# (6.9, 3.8655773617100664)
# (2.3, 1.8263678331819007)
# (1.4, 0.8700531840816983)
# (-0.136, 0.6836905855047704)
# (0.735, 0.6942935416569687)
# (0.653, 0.7223634622065471)
# (1.0, 0.7421091747601749)
# (0.568, 0.6134193087838185)
# (0.6990000000000001, 1.0164937103470362)
# (0.614, 0.6920496006607424)
# (0.16699999999999998, 0.5637213759951782)
# (4.6, 1.7644505399292858)
# (1.6, 1.165962026738787)
# (0.866, 0.699688290984469)
# (0.327, 0.6140877025728448)
# (0.825, 1.4102397987163457)
# (0.977, 0.624558819881889)
# (0.439, 0.4644679519962964)
# (1.2, 0.38411039313432127)
# (1.9, 1.0921662924397284)
# (0.34700000000000003, 0.8613077008247565)
# (0.627, 0.6330576632602511)
# (0.474, 0.5515668317106477)
# (-3.2, 0.5469319438979778)
# (0.249, 0.5782132990992039)
# [0.61625925 0.64763919 0.64252637 0.95950645 1.53858537 0.56312123
#  0.62924595 0.54439325 0.54729614 0.63491508 0.6113741  1.21984582
#  1.46241397 0.63113501 0.84752538 0.66002128 0.47415629 0.65773151
#  0.58515975 0.75029012 0.7215376  1.18875379 0.46276337 0.95232776
#  0.61901072 0.45958392 0.78280438 0.54489837 2.1045898  0.60144755
#  0.48887627 1.0258446  0.91590038 0.55103764 0.70875823 0.640771
#  0.77389682 0.45759851 1.42670709 1.40010266 0.80382762 0.88165355
#  0.97240642 0.92037218 0.68485014 0.9901761  0.47974878 1.6766646
#  0.75360558 2.64376377 0.82383455 1.00262114 0.68036099 0.97887122
#  0.69511909 0.65819485 0.56700251 1.8522111  0.78738678 4.56153277
#  0.7351036  0.68549057 0.65553303 1.46356531 0.79545837 0.68395725
#  0.6979281  0.9295844  1.74234113 0.72691936 3.3100246  0.69110585
#  1.52126046 0.548326   0.95435235 0.5867693  0.79957839 0.45139293
#  0.73899592 0.71519245 1.19970895 0.56594961 0.85961825 0.55390823
#  0.53627389 0.97257109 0.68230679 1.57197338 1.19067168 0.63521107
#  0.71282213 0.97730894 0.69888909 0.69900123 0.5947327  0.69540491
#  0.43695954 0.71659596 4.55953969 1.53416907 0.89557859 1.16017402
#  0.78675911 0.82467452 0.74665996 0.69994146 0.52643371 0.5899067
#  0.71029423 1.19292538 0.93632578 0.80833017 0.54550583 1.71923478
#  0.57001145 0.78324641 0.82925462 0.52105716 0.51260642 0.90636423
#  0.8537446  0.58591531 1.17724915 2.14940664 1.27226207 0.73222636
#  3.86557736 1.82636783 0.87005318 0.68369059 0.69429354 0.72236346
#  0.74210917 0.61341931 1.01649371 0.6920496  0.56372138 1.76445054
#  1.16596203 0.69968829 0.6140877  1.4102398  0.62455882 0.46446795
#  0.38411039 1.09216629 0.8613077  0.63305766 0.55156683 0.54693194
#  0.5782133 ]

# %% [markdown]
# # Корректирование моделей

# %% [markdown]
# #### XGBRegressor

# %%
xgb_grid_params = {
    'n_estimators': [10, 20, 50, 100, 200, 300, 500, 600, 700]
}

xgb_grid = GridSearchCV(XGBRegressor(), xgb_grid_params, cv = 10)
xgb_grid.fit(X_train, y_train)
# Out:
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:22:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=1, verbosity=1),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'n_estimators': [10, 20, 50, 100, 200, 300, 500, 600, 700]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
print("Лучший результат модели XGBoost с использованием GridSearchCV:",
      xgb_grid.best_score_)
print("Наилучшие значения параметров: {}".format(xgb_grid.best_params_))
# Out:
# Лучший результат модели XGBoost с использованием GridSearchCV: 0.5936804431444888
# Наилучшие значения параметров: {'n_estimators': 500}

# %% [markdown]
# #### RFR

# %%
rfr_grid_params = {
    'max_depth': [1, 2, 5, 10, 20],
    'n_estimators': [1, 5, 10, 50, 100, 200]
}

rfr_grid = GridSearchCV(RandomForestRegressor(), rfr_grid_params, cv=10)
rfr_grid.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'max_depth': [1, 2, 5, 10, 20], 'n_estimators': [1, 5, 10, 50, 100, 200]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
print("Лучший результат модели RandomForestRegressor с использованием GridSearchCV:",
      rfr_grid.best_score_)
print("Наилучшие значения параметров: {}".format(rfr_grid.best_params_))
predict_test(rfr_grid, X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# Лучший результат модели RandomForestRegressor с использованием GridSearchCV: 0.613998403139917
# Наилучшие значения параметров: {'max_depth': 20, 'n_estimators': 100}
# root mean_squared_error train / test: 0.728 / 1.314
# r2_score train / test: 0.953 / 0.622

# %% [markdown]
# #### SVR

# %%
svr_grid_params = {'C': np.array([0.1, 1, 10, 100]), 'gamma': np.array([0.001, 0.01, 0.1, 1, 10])}
svr_grid = GridSearchCV(SVR(), svr_grid_params, cv=10)
svr_grid.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'C': array([  0.1,   1. ,  10. , 100. ]), 'gamma': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
print("Наил знач правильности перекр проверки: {:.2f}".format(svr_grid.best_score_))
print("Наил знач правильности на тесте: {:.2f}".format(svr_grid.score(X_test_scaled, y_test)))
print("Наил параметры: ", svr_grid.best_params_)
# Out:
# Наил знач правильности перекр проверки: 0.59
# Наил знач правильности на тесте: 0.75
# Наил параметры:  {'C': 100.0, 'gamma': 0.1}

# %%
compare_predictions(svr_grid, X_test_scaled, y_test)
# Out:
# (0.43700000000000006, 0.4042220686264617)
# (0.6579999999999999, 0.5537863545624138)
# (-0.44, 0.2778949875745642)
# (0.17600000000000002, 1.7705681917623597)
# (2.3, 2.328510435505601)
# (0.797, 0.7070413760391805)
# (0.696, 0.5459253727378783)
# (0.457, 0.5087838083844591)
# (0.512, 0.21402636968482547)
# (0.49200000000000005, 0.5057406550701504)
# (-0.444, 0.446151885267037)
# (2.2, 2.1180992216043624)
# (2.9, 2.386606426296206)
# (1.2, 0.47260843482673387)
# (1.6, 0.9091328910744014)
# (-0.036000000000000004, 0.7616201840597032)
# (0.345, 0.17398341986537424)
# (0.649, 0.4509152489253925)
# (0.7340000000000001, 0.45084430204418346)
# (0.821, 1.0354780016484657)
# (0.513, 0.6610576709670912)
# (3.8, 2.234548996291048)
# (0.075, 0.1375824199891813)
# (1.6, 1.4558958804253965)
# (0.457, 0.47255170802304214)
# (0.146, 0.253976669935577)
# (0.424, 0.5854809541374184)
# (0.083, 0.20341617489254737)
# (0.9490000000000001, 2.9228426839912576)
# (0.478, 0.39893895693671233)
# (0.249, 0.16424136483713347)
# (1.1, 1.5637687219293444)
# (1.2, 1.0896642956970712)
# (0.418, 0.28539722006881085)
# (0.425, 0.37532666872633946)
# (1.0, 0.8255299763787836)
# (2.0, 0.8528810118771535)
# (-0.11, 0.19328019033241084)
# (3.6, 2.0951676724620203)
# (3.0, 2.6595224675360303)
# (-2.0, 0.6792218343590495)
# (1.2, 1.0740315513752936)
# (1.7, 1.261793493534208)
# (2.4, 1.1779634217616834)
# (0.836, 0.7557780086097328)
# (1.5, 1.1993528746501685)
# (0.19399999999999998, 0.3033902614195032)
# (4.7, 4.195802242741232)
# (0.41700000000000004, 0.7131265545926002)
# (4.6, 3.8723792473813834)
# (-6.2, 0.7850583278699137)
# (0.47700000000000004, 1.2434872746736776)
# (0.431, 0.4369669505059566)
# (1.2, 1.6094355783075205)
# (0.46799999999999997, 0.6398732182877129)
# (0.031, 0.568341760198118)
# (1.1, 0.6097443728070093)
# (1.2, 4.335916489611714)
# (1.8, 0.8826124590546787)
# (10.0, 12.514020145513536)
# (0.489, 0.7252450568331259)
# (1.7, 0.9196673462918827)
# (0.42700000000000005, 0.4700261559270249)
# (3.8, 3.4173625782644255)
# (1.2, 1.6016528608649825)
# (0.902, 0.6780463074786329)
# (0.431, 0.5581125902056474)
# (1.8, 1.5323648538667047)
# (4.3, 3.6493772762808394)
# (0.539, 0.5158202641265408)
# (10.1, 7.200728633598837)
# (1.1, 1.0618325094328984)
# (4.5, 3.6301894728113897)
# (0.314, 0.39540398605736904)
# (1.4, 1.2618768775494065)
# (1.6, 0.5309513905015368)
# (0.469, 0.6266099298088879)
# (0.105, 0.23406606116594197)
# (1.1, 0.80463478514414)
# (0.281, 0.4427407325013437)
# (2.7, 2.0455555271066945)
# (0.256, 0.32538507877658596)
# (1.3, 0.9127675322994779)
# (0.252, 0.47021333144257405)
# (0.449, 0.2721707938968283)
# (1.4, 1.417837770986944)
# (0.6679999999999999, 0.5273233379162381)
# (2.0, 3.9014250506191903)
# (2.2, 1.9967938954146778)
# (0.45799999999999996, 0.6097615771665037)
# (0.758, 0.8043817773693522)
# (1.1, 0.9906782079477612)
# (0.473, 0.7112697624737994)
# (0.41600000000000004, 0.7096971922165611)
# (0.495, 0.542643100444204)
# (1.3, 0.9895506093884396)
# (0.125, 0.20088294444813393)
# (0.659, 0.8579027408716033)
# (16.4, 14.334055222483736)
# (1.5, 2.6420358307755922)
# (2.0, 0.7978049726805612)
# (2.1, 2.224049371199678)
# (0.106, 0.8738452372291281)
# (0.613, 0.5260760935724509)
# (0.664, 0.5758943223255475)
# (0.6679999999999999, 0.6439411668417936)
# (0.485, 0.46842732704899426)
# (0.203, 0.29093411205576025)
# (0.935, 0.5889956466392849)
# (1.0, 1.4514169309844736)
# (1.5, 2.1019236138103654)
# (1.7, 1.4154629998727248)
# (0.27, 0.3870462749026675)
# (1.7, 2.538161399337435)
# (-2.1, 0.2737746940920349)
# (-3.6, 1.0630118331548122)
# (0.821, 0.9294231821287102)
# (0.846, 0.31777043332038524)
# (0.5720000000000001, 0.2666773315197677)
# (0.568, 1.172954418913429)
# (1.4, 1.2336433867983008)
# (0.655, 0.4985060507134964)
# (1.7, 1.5784724479101673)
# (0.483, 2.2074802479089417)
# (2.5, 2.340392709760488)
# (0.965, 0.8427986146426267)
# (6.9, 8.345877250135056)
# (2.3, 2.952517486346446)
# (1.4, 0.8727894983568749)
# (-0.136, 0.5089975823279875)
# (0.735, 0.5547236231532171)
# (0.653, 0.6463396248711124)
# (1.0, 1.0595527397036566)
# (0.568, 0.643701901037014)
# (0.6990000000000001, 1.331243489017064)
# (0.614, 0.6091968750903423)
# (0.16699999999999998, 0.491437541821492)
# (4.6, 3.280381954080662)
# (1.6, 2.430830496262738)
# (0.866, 0.8713609251923717)
# (0.327, 0.31415888957145377)
# (0.825, 1.4190073304669486)
# (0.977, 0.4839161419357172)
# (0.439, 0.2877629954825185)
# (1.2, -0.007215588296878295)
# (1.9, 1.690679061110183)
# (0.34700000000000003, 1.3667369114373091)
# (0.627, 0.6529766593552839)
# (0.474, 0.39750454353883846)
# (-3.2, 0.3743804708376022)
# (0.249, 0.38585480523313187)
# [ 4.04222069e-01  5.53786355e-01  2.77894988e-01  1.77056819e+00
#   2.32851044e+00  7.07041376e-01  5.45925373e-01  5.08783808e-01
#   2.14026370e-01  5.05740655e-01  4.46151885e-01  2.11809922e+00
#   2.38660643e+00  4.72608435e-01  9.09132891e-01  7.61620184e-01
#   1.73983420e-01  4.50915249e-01  4.50844302e-01  1.03547800e+00
#   6.61057671e-01  2.23454900e+00  1.37582420e-01  1.45589588e+00
#   4.72551708e-01  2.53976670e-01  5.85480954e-01  2.03416175e-01
#   2.92284268e+00  3.98938957e-01  1.64241365e-01  1.56376872e+00
#   1.08966430e+00  2.85397220e-01  3.75326669e-01  8.25529976e-01
#   8.52881012e-01  1.93280190e-01  2.09516767e+00  2.65952247e+00
#   6.79221834e-01  1.07403155e+00  1.26179349e+00  1.17796342e+00
#   7.55778009e-01  1.19935287e+00  3.03390261e-01  4.19580224e+00
#   7.13126555e-01  3.87237925e+00  7.85058328e-01  1.24348727e+00
#   4.36966951e-01  1.60943558e+00  6.39873218e-01  5.68341760e-01
#   6.09744373e-01  4.33591649e+00  8.82612459e-01  1.25140201e+01
#   7.25245057e-01  9.19667346e-01  4.70026156e-01  3.41736258e+00
#   1.60165286e+00  6.78046307e-01  5.58112590e-01  1.53236485e+00
#   3.64937728e+00  5.15820264e-01  7.20072863e+00  1.06183251e+00
#   3.63018947e+00  3.95403986e-01  1.26187688e+00  5.30951391e-01
#   6.26609930e-01  2.34066061e-01  8.04634785e-01  4.42740733e-01
#   2.04555553e+00  3.25385079e-01  9.12767532e-01  4.70213331e-01
#   2.72170794e-01  1.41783777e+00  5.27323338e-01  3.90142505e+00
#   1.99679390e+00  6.09761577e-01  8.04381777e-01  9.90678208e-01
#   7.11269762e-01  7.09697192e-01  5.42643100e-01  9.89550609e-01
#   2.00882944e-01  8.57902741e-01  1.43340552e+01  2.64203583e+00
#   7.97804973e-01  2.22404937e+00  8.73845237e-01  5.26076094e-01
#   5.75894322e-01  6.43941167e-01  4.68427327e-01  2.90934112e-01
#   5.88995647e-01  1.45141693e+00  2.10192361e+00  1.41546300e+00
#   3.87046275e-01  2.53816140e+00  2.73774694e-01  1.06301183e+00
#   9.29423182e-01  3.17770433e-01  2.66677332e-01  1.17295442e+00
#   1.23364339e+00  4.98506051e-01  1.57847245e+00  2.20748025e+00
#   2.34039271e+00  8.42798615e-01  8.34587725e+00  2.95251749e+00
#   8.72789498e-01  5.08997582e-01  5.54723623e-01  6.46339625e-01
#   1.05955274e+00  6.43701901e-01  1.33124349e+00  6.09196875e-01
#   4.91437542e-01  3.28038195e+00  2.43083050e+00  8.71360925e-01
#   3.14158890e-01  1.41900733e+00  4.83916142e-01  2.87762995e-01
#  -7.21558830e-03  1.69067906e+00  1.36673691e+00  6.52976659e-01
#   3.97504544e-01  3.74380471e-01  3.85854805e-01]
